# %%
from __future__ import division
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import pickle
import glob

# %%
size = 7737578
count = 2402105

# %%
size = 0
#types = [["NuECC", 0],["NuENC", 1],["NuMuCC", 2],["NuMuNC", 3],["NuTauCC", 4],["NuTauNC", 5]]
types = [["NuTauCC", 4]]

for t in types:
    for name in glob.glob('/home/dup193/work/double_pulse/data/Nu_all/'+t[0]+'*_info.pkl'):
        x = np.load(name, mmap_mode="r",allow_pickle=True)
        print(name, len(x), t[1])
        size = size +len(x)
print(size)
# Out:
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_7_000062_info.pkl 7777 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_11_000108_info.pkl 7553 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_9_000084_info.pkl 7630 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_6_000055_info.pkl 7542 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_12_000114_info.pkl 7446 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_7_000063_info.pkl 7651 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_8_000079_info.pkl 7688 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_12_000112_info.pkl 7784 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_10_000094_info.pkl 7577 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_2_000011_info.pkl 7561 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_2_000016_info.pkl 7731 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_13_000120_info.pkl 85 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_1_000006_info.pkl 7702 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_9_000081_info.pkl 7570 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_11_000105_info.pkl 7571 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_9_000089_info.pkl 7602 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_9_000085_info.pkl 7680 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_8_000070_info.pkl 7646 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_2_000013_info.pkl 7648 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_3_000029_info.pkl 7735 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_11_000100_info.pkl 7724 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_6_000059_info.pkl 7586 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_3_000027_info.pkl 7612 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_10_000099_info.pkl 7605 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_5_000043_info.pkl 7705 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_2_000019_info.pkl 7656 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_6_000056_info.pkl 7645 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_4_000030_info.pkl 7562 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_4_000033_info.pkl 7498 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_8_000076_info.pkl 7589 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_11_000102_info.pkl 7755 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_6_000050_info.pkl 7775 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_12_000111_info.pkl 7566 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_9_000086_info.pkl 7439 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_9_000082_info.pkl 7592 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_7_000068_info.pkl 7656 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_6_000057_info.pkl 7691 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_9_000087_info.pkl 7762 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_7_000061_info.pkl 7490 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_1_000008_info.pkl 7566 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_1_000005_info.pkl 7713 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_3_000023_info.pkl 7828 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_5_000048_info.pkl 7673 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_10_000098_info.pkl 7609 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_7_000066_info.pkl 7655 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_3_000020_info.pkl 7663 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_8_000074_info.pkl 7679 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_2_000018_info.pkl 7579 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_7_000064_info.pkl 7760 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_8_000073_info.pkl 7715 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_10_000096_info.pkl 7609 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_4_000035_info.pkl 7651 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_1_000003_info.pkl 7661 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_4_000032_info.pkl 7544 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_6_000052_info.pkl 7715 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_9_000080_info.pkl 7557 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_12_000115_info.pkl 7720 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_12_000118_info.pkl 7674 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_1_000007_info.pkl 7689 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_5_000042_info.pkl 7671 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_10_000097_info.pkl 7536 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_3_000021_info.pkl 7691 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_3_000025_info.pkl 7641 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_11_000106_info.pkl 7655 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_11_000109_info.pkl 7649 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_5_000047_info.pkl 7595 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_10_000093_info.pkl 7645 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_3_000028_info.pkl 7601 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_10_000095_info.pkl 7581 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_12_000110_info.pkl 7624 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_5_000040_info.pkl 7698 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_4_000031_info.pkl 7637 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_8_000071_info.pkl 7777 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_2_000017_info.pkl 7635 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_9_000083_info.pkl 7755 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_11_000104_info.pkl 7552 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_7_000067_info.pkl 7478 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_3_000024_info.pkl 7709 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_2_000015_info.pkl 7526 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_5_000041_info.pkl 7552 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_8_000078_info.pkl 7608 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_2_000012_info.pkl 7702 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_5_000045_info.pkl 7604 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_1_000002_info.pkl 7676 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_12_000117_info.pkl 7567 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_6_000053_info.pkl 7718 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_10_000092_info.pkl 7629 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_1_000009_info.pkl 7724 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_8_000075_info.pkl 7734 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_5_000049_info.pkl 7732 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_4_000034_info.pkl 7622 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_3_000022_info.pkl 7612 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_8_000077_info.pkl 7495 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_4_000036_info.pkl 7741 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_4_000039_info.pkl 7569 4
# /home/dup193/work/double_pulse/data/Nu_all/NuTauCC_Qtot2000_Qst600_12_

#        {'dom_position': (210.47000122070312, -209.77000427246094, -183.88999938964844), 'key': (19, 41), 'qdom': 5.949999958276749},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -200.91000366210938), 'key': (19, 42), 'qdom': 7.3000000566244125},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -217.92999267578125), 'key': (19, 43), 'qdom': 9.925000011920929},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -234.9499969482422), 'key': (19, 44), 'qdom': 15.299999952316284},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -251.97000122070312), 'key': (19, 45), 'qdom': 23.89999958872795},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -268.989990234375), 'key': (19, 46), 'qdom': 66.94999991357327},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -286.010009765625), 'key': (19, 47), 'qdom': 85.95000000298023},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -303.0299987792969), 'key': (19, 48), 'qdom': 157.54999993741512},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -320.04998779296875), 'key': (19, 49), 'qdom': 285.02500024437904},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -337.07000732421875), 'key': (19, 50), 'qdom': 407.92500096559525},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -354.0899963378906), 'key': (19, 51), 'qdom': 578.6750032305717},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -371.1099853515625), 'key': (19, 52), 'qdom': 807.3499978482723},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -388.1300048828125), 'key': (19, 53), 'qdom': 1081.4750029146671},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -405.1600036621094), 'key': (19, 54), 'qdom': 929.2750025689602},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -422.17999267578125), 'key': (19, 55), 'qdom': 646.8250000476837},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -439.20001220703125), 'key': (19, 56), 'qdom': 330.94999888539314},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -456.2200012207031), 'key': (19, 57), 'qdom': 197.05000096559525},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -473.239990234375), 'key': (19, 58), 'qdom': 108.50000044703484},
#        {'dom_position': (210.47000122070312, -209.77000427246094, -490.260009765625), 'key': (19, 59), 'qdom': 51.44999969005585}],
#       dtype=object), 'number': 19}, 'tau_direction': (0.5068631635447236, 2.66283623678053), 'nu_energy': 158690.27150522976, 'id': (5400, 4294967295, 106, 0), 'tau_time': (9686.6390035914, 9693.520125295756)}]

# %%
#arr = np.load('/fastio2/dasha/double_pulse/nu_data.npy', mmap_mode = 'r')
arr = np.memmap('/fastio2/dasha/double_pulse/nu_data.npy', mode = 'r', dtype ='float32', shape=(size,300,60))

# %%
arr.bites
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-91ca0532cccf> in <module>
# ----> 1 arr.bites
#
# AttributeError: 'memmap' object has no attribute 'bites'

# %%
pos = 0
nu_info = np.memmap('/fastio2/dasha/double_pulse/nu_info.npy', mode = 'w+', dtype ='float32', shape=(size,3))

types = [["NuECC", 0],["NuENC", 1],["NuMuCC", 2],["NuMuNC", 3],["NuTauCC", 4],["NuTauNC", 5]]
for t in types:
    for name in glob.glob('/home/dup193/work/double_pulse/data/Nu_all/'+t[0]+'*_info.pkl'):
        x = np.load(name, mmap_mode="r",allow_pickle=True)
        for i in x:
            arr = [i['tau_energy'], i['qtotal'], i['strings']['charge']]
            arr = np.array(arr)
            arr = np.float32(arr)
            nu_info[pos:pos+1] = arr
            pos = pos + 1

# %%
nu_info = np.memmap('/fastio2/dasha/double_pulse/nu_info.npy', mode = 'r', dtype ='float32', shape=(size,3))
count = 0
for i in nu_info:
    if i[1]> 10000 and i[2]> 5000:
        count = count +1
print(count)
# Out:
# 2402105

# %%
nu_info_sm = np.memmap('/fastio2/dasha/double_pulse/nu_info_qs5000_qt10000.npy', mode = 'w+', dtype ='float32', shape=(count,3))
nu_info = np.memmap('/fastio2/dasha/double_pulse/nu_info.npy', mode = 'r', dtype ='float32', shape=(size,3))
pos =0
for i in nu_info:
    if i[1]> 10000 and i[2]> 5000:
        nu_info_sm[pos:pos+1] = i
        pos = pos +1

# %%
nu_data_sm = np.memmap('/fastio2/dasha/double_pulse/nu_data_qs5000_qt10000.npy', mode = 'w+', dtype ='float32', shape=(count,300,60))
nu_label_sm = np.memmap('/fastio2/dasha/double_pulse/nu_label_qs5000_qt10000.npy', mode = 'w+', dtype ='float32', shape=count)
nu_data = np.memmap('/fastio2/dasha/double_pulse/nu_data.npy', mode = 'r', dtype ='float32', shape=(size,300,60))
nu_label = np.memmap('/fastio2/dasha/double_pulse/nu_label.npy', mode = 'r', dtype ='float32', shape=size)
pos = 0
for i,inf in enumerate(nu_info):
    if inf[1]> 10000 and inf[2]> 5000:
        nu_data_sm[pos:pos+1] = nu_data[i]
        nu_label_sm[pos:pos+1] = nu_label[i]
        pos = pos + 1

# %%
def GetEnergy(en_arr, qt_arr, qs_arr, ptype):
    for name in glob.glob('/home/dup193/work/double_pulse/data/Nu_all/'+ptype+'*_info.pkl'):
        data = np.load(name, mmap_mode="r", allow_pickle=True)
        for i in data:
            en_arr.append(i['tau_energy'])
            qt_arr.append(i['qtotal'])
            qs_arr.append(i['strings']['charge'])
            
            #n_arr.append(en)
    return

# %%
en_e_cc = []
qt_e_cc = []
qs_e_cc = []
GetEnergy(en_e_cc,qt_e_cc,qs_e_cc,"NuECC")
print(len(en_e_cc), len(qt_e_cc),len(qs_e_cc))
en_e_cc = np.array(en_e_cc)
qt_e_cc = np.array(qt_e_cc)
qs_e_cc = np.array(qs_e_cc)
# Out:
# 2885285 2885285 2885285

# %%
en_e_nc = []
qt_e_nc = []
qs_e_nc = []
GetEnergy(en_e_nc,qt_e_nc,qs_e_nc,"NuENC")
print(len(en_e_nc), len(qt_e_nc),len(qs_e_nc))
en_e_nc = np.array(en_e_nc)
qt_e_nc = np.array(qt_e_nc)
qs_e_nc = np.array(qs_e_nc)
# Out:
# 441544 441544 441544

# %%
en_m_cc = []
qt_m_cc = []
qs_m_cc = []
GetEnergy(en_m_cc,qt_m_cc,qs_m_cc,"NuMuCC")
print(len(en_m_cc), len(qt_m_cc),len(qs_m_cc))
en_m_cc = np.array(en_m_cc)
qt_m_cc = np.array(qt_m_cc)
qs_m_cc = np.array(qs_m_cc)
# Out:
# 2960557 2960557 2960557

# %%
en_m_nc = []
qt_m_nc = []
qs_m_nc = []
GetEnergy(en_m_nc,qt_m_nc,qs_m_nc,"NuMuNC")
print(len(en_m_nc), len(qt_m_nc),len(qs_m_nc))
en_m_nc = np.array(en_m_nc)
qt_m_nc = np.array(qt_m_nc)
qs_m_nc = np.array(qs_m_nc)
# Out:
# 370980 370980 370980

# %%
en_t_cc = []
qt_t_cc = []
qs_t_cc = []
GetEnergy(en_t_cc,qt_t_cc,qs_t_cc,"NuTauCC")
print(len(en_t_cc), len(qt_t_cc),len(qs_t_cc))
en_t_cc = np.array(en_t_cc)
qt_t_cc = np.array(qt_t_cc)
qs_t_cc = np.array(qs_t_cc)
# Out:
# 909096 909096 909096

# %%
en_t_nc = []
qt_t_nc = []
qs_t_nc = []
GetEnergy(en_t_nc,qt_t_nc,qs_t_nc,"NuTauNC")
print(len(en_t_nc), len(qt_t_nc),len(qs_t_nc))
en_t_nc = np.array(en_t_nc)
qt_t_nc = np.array(qt_t_nc)
qs_t_nc = np.array(qs_t_nc)
# Out:
# 170116 170116 170116

# %%
def Plot(arr1, name, bs =100, r = [100,100000], lab = "Energy, GeV", scale = "linear"):
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111)
    plt.ticklabel_format(axis='both', style='sci', scilimits=(-5,5))
    weights1 = np.ones_like(arr1)/float(len(arr1))
    ax.set_xscale(scale)
    ax.set_yscale('log')
    ax.set_title(name, fontsize = 14)
    ax.text(0.5,0.95,'#Events '+str(len(arr1)), transform=ax.transAxes, color = "black",fontsize=12)
    ax.set_xlabel(lab, fontsize = 14)                                                              
    ax.set_ylabel("FractionEvents", fontsize = 14)                                                   
    ax.hist(arr1, bins =bs, weights= weights1, range = r, histtype = 'step',edgecolor ='r', fill= False,)

# %%
Plot(en_e_cc, 'NuECC')
Plot(en_e_nc, 'NuENC')
Plot(en_m_cc, 'NuMuCC')
Plot(en_m_nc, 'NuMuNC')
Plot(en_t_cc, 'NuTauCC')
Plot(en_t_nc, 'NuTauNC')

# %%
Plot(qt_e_cc, 'NuECC', r= [1000, 20000], lab = "Qtot, PE", scale = 'linear')
Plot(qt_e_nc, 'NuENC', r= [1000, 20000], lab = "Qtot, PE", scale = 'linear')
Plot(qt_m_cc, 'NuMuCC', r= [1000, 20000], lab = "Qtot, PE", scale = 'linear')
Plot(qt_m_nc, 'NuMuNC', r= [1000, 20000], lab = "Qtot, PE", scale = 'linear')
Plot(qt_t_cc, 'NuTauCC', r= [1000, 20000], lab = "Qtot, PE", scale = 'linear')
Plot(qt_t_nc, 'NuTauNC', r= [1000, 20000], lab = "Qtot, PE", scale = 'linear')

# %%
Plot(new_en_e_cc, 'NuECC', r= [0, 1000000], scale = 'linear')

# %%
new_en_e_cc = []
for i, qt in enumerate(qt_e_cc):
    if qt > 4000:
        new_en_e_cc.append(en_e_cc[i])
new_en_e_cc = np.array(new_en_e_cc)

# %%
Plot(qs_e_cc, 'NuECC', r= [100, 20000], lab = "Qst, PE", scale = 'linear')
Plot(qs_e_nc, 'NuENC', r= [100, 20000], lab = "Qst, PE", scale = 'linear')
Plot(qs_m_cc, 'NuMuCC', r= [100, 20000], lab = "Qst, PE", scale = 'linear')
Plot(qs_m_nc, 'NuMuNC', r= [100, 20000], lab = "Qst, PE", scale = 'linear')
Plot(qs_t_cc, 'NuTauCC', r= [100, 20000], lab = "Qst, PE", scale = 'linear')
Plot(qs_t_nc, 'NuTauNC', r= [100, 20000], lab = "Qst, PE", scale = 'linear')

# %%
def Plot2(arr1, arr2, arr3, name, bs =100, r = [1000,1000000], lab = "Energy, GeV", scale = "linear"):
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111)
   # plt.ticklabel_format(axis='both', style='sci', scilimits=(-5,5))
    weights1 = np.ones_like(arr1)/float(len(arr1))
    weights2 = np.ones_like(arr2)/float(len(arr2))
    weights3 = np.ones_like(arr3)/float(len(arr3))
    
    #ax.set_xscale(scale)
    #ax.set_yscale('log')
    ax.set_title(name, fontsize = 14)
    ax.text(0.5,0.95,'#Events '+str(len(arr1)), transform=ax.transAxes, color = "black",fontsize=12)
    ax.text(0.5,0.90,'#Events '+str(len(arr2)), transform=ax.transAxes, color = "black",fontsize=12)
    ax.text(0.5,0.85,'#Events '+str(len(arr3)), transform=ax.transAxes, color = "black",fontsize=12)
    
    ax.set_xlabel(lab, fontsize = 14)                                                                                                                           
    #ax.set_ylabel("FractionEvents", fontsize = 14)                                                   
    ax.hist(arr1, bins =bs, range = r, histtype = 'step',edgecolor ='r', fill= False)  
    ax.hist(arr2, bins =bs, range = r, histtype = 'step',edgecolor ='b', fill= False)  
    ax.hist(arr3, bins =bs, range = r, histtype = 'step',edgecolor ='g', fill= False)

# %%
new_qt_t_cc = []
new_en_t_cc = []
new2_qt_t_cc = []
new2_en_t_cc = []
for i, qs in enumerate(qs_t_cc):
    qt = qt_t_cc[i]
    if (qs > 5000) and (qt > 10000):
        new_qt_t_cc.append(qt_t_cc[i])
        new_en_t_cc.append(en_t_cc[i])
    else:
        new2_qt_t_cc.append(qt_t_cc[i])
        new2_en_t_cc.append(en_t_cc[i])

new_qt_t_cc = np.array(new_qt_t_cc)
new_en_t_cc = np.array(new_en_t_cc)
new2_qt_t_cc = np.array(new2_qt_t_cc)
new2_en_t_cc = np.array(new2_en_t_cc)

# %%
Plot2(new_qt_t_cc, new2_qt_t_cc, qt_t_cc, 'NuTauCC', r= [100, 20000], lab = "Qt, PE", scale = 'linear')
Plot2(new_en_t_cc, new2_en_t_cc, en_t_cc, 'NuTauCC', r= [1000, 1000000], lab = "En", scale = 'linear')

# %%
def Plot2d(arr1, arr2, name, bs =[100,100], r = [[1000,1000000],[500,50000]], labx = "Energy, GeV", laby = "Qt, PE", scale = "linear"):
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111)
   # plt.ticklabel_format(axis='both', style='sci', scilimits=(-5,5))
    #weights1 = np.ones_like(arr1)/float(len(arr1))
    #ax.set_xscale(scale)
    #ax.set_yscale('log')
    ax.set_title(name, fontsize = 14)
    ax.text(0.5,0.95,'#Events '+str(len(arr1)), transform=ax.transAxes, color = "black",fontsize=12)
    ax.set_xlabel(labx, fontsize = 14)                                                              
    ax.set_ylabel(laby, fontsize = 14)                                                              
    #ax.set_ylabel("FractionEvents", fontsize = 14)                                                   
    ax.hist2d(arr1, arr2, bins =bs, range = r,norm=mpl.colors.LogNorm())

# %%
Plot2d(new_en_t_cc, new_qt_t_cc, 'NuECC')
#Plot2d(new_en_t_cc, new_qs_t_cc, 'NuECC', laby = "Qs, PE", )
