# %%
from __future__ import division
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import pickle
from operator import itemgetter
import sklearn
import matplotlib.colors as colors
from sklearn.cluster import MeanShift
from itertools import cycle
from scipy import ndimage

# %%
c =0.299792458
n =1.3195
v=c/n 
print(v)
# Out:
# 0.2272015596816976

# %%
info = pickle.load(open("../data/Format_test_info.pkl", "rb"))
data = np.load("../data/Format_test_data.npy",allow_pickle=True,encoding='bytes')
print(len(info), len(data))
# Out:
# 2 8

# %%
print(len(info[1]["strings"]))
# Out:
# 2

# %%
for im in data:
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')

# %%
info3 = pickle.load(open("../data/Tau05to15PeV_2_info.pkl", "rb"))
data3 = np.load("../data/Tau05to15PeV_2_data.npy",allow_pickle=True,encoding='bytes')
print(len(info3), len(data3))
# Out:
# 944 4379

# %%
for im in data3[:10]:
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')

# %%
infoE = pickle.load(open("../data/Electron05to15PeV_0_info.pkl", "rb"))
dataE = np.load("../data/Electron05to15PeV_0_data.npy",allow_pickle=True,encoding='bytes')
print(len(infoE), len(dataE))
# Out:
# 2367 12630

# %%
for im in dataE[:10]:
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')
