# %%
from __future__ import division
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
c =0.299792458
n =1.3195
v=c/n 
print(v)
# Out:
# 0.2272015596816976

# %%
info = pickle.load(open("WeirdNutau_info.pkl", "rb"))
data = np.load("WeirdNutau_data.npy",allow_pickle=True,encoding='bytes')
print(len(info), np.max(data), np.min(data))
# Out:
# 285 4.302569428347692e-09 -5.973782291515215e-11

# %%
print(len(info[1]["strings"]))
# Out:
# 3

# %%
for im in data[:10]:
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')
