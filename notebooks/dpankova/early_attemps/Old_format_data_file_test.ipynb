# %%
from __future__ import division
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import pickle
from operator import itemgetter
import sklearn
import matplotlib.colors as colors
from sklearn.cluster import MeanShift
from itertools import cycle
from scipy import ndimage

# %%
c =0.299792458
n =1.3195
v=c/n 
print(v)
# Out:
# 0.2272015596816976

# %%
info_EC = pickle.load(open("../data/Cascade_Info/NuECC_Qtot2000_Qst600_9_000080_info.pkl", "rb"))
data_EC = np.load("../data/Cascade/NuECC_Qtot2000_Qst600_9_000080_data.npy",allow_pickle=True,encoding='bytes')
print(len(info_EC), len(data_EC))
# Out:
# 23867 23867

# %%
for i, im in enumerate(data_EC[:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    print(type(im[0][0]))
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')
    print(info_EC[i])
# Out:
# <class 'numpy.float64'>
# {'index': 0, 'tau_length': 0.0, 'tau_position': (-69.7364226508162, -452.3322457337, 176.83657997611317), 'qtotal': 5082.974996397272, 'tau_energy': 42367.76589335244, 'strings': {'charge': 2055.550000488758, 'doms': array([{'dom_position': (-88.05000305175781, -384.29998779296875, 346.8299865722656), 'key': (9, 10), 'qdom': 0.7749999761581421},
#        {'dom_position': (-88.05000305175781, -384.29998779296875, 329.80999755859375), 'key': (9, 11), 'qdom': 1.225000023841858},
#        {'dom_position': (-88.05000305175781, -384.29998779296875, 295.7699890136719), 'key': (9, 13), 'qdom': 3.8000000715255737},
#        {'dom_position': (-88.05000305175781, -384.29998779296875, 278.75), 'key': (9, 14), 'qdom': 7.524999916553497},
#        {'dom_position': (-88.05000305175781, -384.29998779296875, 227.67999267578125), 'key': (9, 17), 'qdom': 34.22499978542328},
# ...

# %%
info_EN = pickle.load(open("../data/Cascade_Info/NuENC_Qtot2000_Qst600_1_info.pkl", "rb"))
data_EN = np.load("../data/Cascade/NuENC_Qtot2000_Qst600_1_data.npy",allow_pickle=True,encoding='bytes')
print(len(info_EN), len(data_EN))
# Out:
# 36695 36695

# %%
for i, im in enumerate(data_EN[:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')
    print(info_EN[i])
# Out:
# {'index': 0, 'tau_length': nan, 'tau_position': (-440.9373848313055, -146.29338223288005, 376.27289845616747), 'qtotal': 112311.07511706464, 'tau_energy': 502654.2585593589, 'strings': {'charge': 104504.7001131177, 'doms': array([{'dom_position': (-447.739990234375, -113.12999725341797, 500.6700134277344), 'key': (32, 1), 'qdom': 62.000000178813934},
#        {'dom_position': (-447.739990234375, -113.12999725341797, 483.6499938964844), 'key': (32, 2), 'qdom': 232.22500053048134},
#        {'dom_position': (-447.739990234375, -113.12999725341797, 466.6300048828125), 'key': (32, 3), 'qdom': 461.7250004708767},
#        {'dom_position': (-447.739990234375, -113.12999725341797, 449.6099853515625), 'key': (32, 4), 'qdom': 928.6499997675419},
#        {'dom_position': (-447.739990234375, -113.12999725341797, 432.5899963378906), 'key': (32, 5), 'qdom': 2123.2750034332275},
# ...

# %%
info_MC = pickle.load(open("../data/Track_Info/NuMuCC_Qtot2000_Qst600_1_000000_info.pkl", "rb"))
data_MC = np.load("../data/Track/NuMuCC_Qtot2000_Qst600_1_000000_data.npy",allow_pickle=True,encoding='bytes')
print(len(info_MC), len(data_MC))
# Out:
# 24443 24443

# %%
for i, im in enumerate(data_MC[:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')
    print(info_MC[i])
# Out:
# {'index': 0, 'tau_length': 7407.555518737701, 'tau_position': (206.2829690730964, -687.6241148616718, 253.27778200643434), 'qtotal': 2691.4750047866255, 'tau_energy': 190098.2083156979, 'strings': {'charge': 1014.775001719594, 'doms': array([{'dom_position': (371.55999755859375, -92.18000030517578, 161.1699981689453), 'key': (29, 21), 'qdom': 1.125},
#        {'dom_position': (371.55999755859375, -92.18000030517578, 145.14999389648438), 'key': (29, 22), 'qdom': 1.6500000357627869},
#        {'dom_position': (371.55999755859375, -92.18000030517578, 127.12999725341797), 'key': (29, 23), 'qdom': 2.349999964237213},
#        {'dom_position': (371.55999755859375, -92.18000030517578, 111.11000061035156), 'key': (29, 24), 'qdom': 6.5000001192092896},
#        {'dom_position': (371.55999755859375, -92.18000030517578, 93.08999633789062), 'key': (29, 25), 'qdom': 24.575000122189522},
# ...

# %%
info_MN = pickle.load(open("../data/Cascade_Info/NuMuNC_Qtot2000_Qst600_1_info.pkl", "rb"))
data_MN = np.load("../data/Cascade/NuMuNC_Qtot2000_Qst600_1_data.npy",allow_pickle=True,encoding='bytes')
print(len(info_MN), len(data_MN))
# Out:
# 30767 30767

# %%
for i, im in enumerate(data_MN[:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')
    print(info_MN[i])
# Out:
# {'index': 0, 'tau_length': nan, 'tau_position': (-360.1994768027216, 221.50502104725456, 63.54091789573431), 'qtotal': 2396.225000400096, 'tau_energy': 7626.570509607701, 'strings': {'charge': 1732.1749997325242, 'doms': array([{'dom_position': (-313.6000061035156, 237.44000244140625, 279.9200134277344), 'key': (61, 14), 'qdom': 0.9750000238418579},
#        {'dom_position': (-313.6000061035156, 237.44000244140625, 262.8999938964844), 'key': (61, 15), 'qdom': 0.9750000238418579},
#        {'dom_position': (-313.6000061035156, 237.44000244140625, 228.86000061035156), 'key': (61, 17), 'qdom': 3.074999988079071},
#        {'dom_position': (-313.6000061035156, 237.44000244140625, 211.83999633789062), 'key': (61, 18), 'qdom': 4.27499994635582},
#        {'dom_position': (-313.6000061035156, 237.44000244140625, 194.82000732421875), 'key': (61, 19), 'qdom': 8.77499994635582},
# ...

# %%
info_TC = pickle.load(open("../data/DoublePulse_Info/NuTauCC_Qtot2000_Qst600_1_000000_info.pkl", "rb"))
data_TC = np.load("../data/DoublePulse/NuTauCC_Qtot2000_Qst600_1_000000_data.npy",allow_pickle=True,encoding='bytes')
print(len(info_TC), len(data_TC))
# Out:
# 7550 7550

# %%
for i, im in enumerate(data_TC[:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')
    print(info_TC[i])
# Out:
# {'index': 0, 'tau_length': 1.474896725285706, 'tau_position': (-255.12681198226437, -84.54156662850369, -442.3124709346016), 'qtotal': 2093.6249975506216, 'tau_energy': 20328.337540350072, 'strings': {'charge': 1103.6499970853329, 'doms': array([{'dom_position': (-200.5500030517578, -74.02999877929688, -242.50999450683594), 'key': (34, 46), 'qdom': 0.9750000238418579},
#        {'dom_position': (-200.5500030517578, -74.02999877929688, -276.54998779296875), 'key': (34, 48), 'qdom': 0.4999999850988388},
#        {'dom_position': (-200.5500030517578, -74.02999877929688, -293.57000732421875), 'key': (34, 49), 'qdom': 0.22499999403953552},
#        {'dom_position': (-200.5500030517578, -74.02999877929688, -310.5899963378906), 'key': (34, 50), 'qdom': 11.77500006556511},
#        {'dom_position': (-200.5500030517578, -74.02999877929688, -327.6099853515625), 'key': (34, 51), 'qdom': 10.10000005364418},
# ...

# %%
info_TN = pickle.load(open("../data/Cascade_Info/NuTauNC_Qtot2000_Qst600_1_info.pkl", "rb"))
data_TN = np.load("../data/Cascade/NuTauNC_Qtot2000_Qst600_1_data.npy",allow_pickle=True,encoding='bytes')
print(len(info_TN), len(data_TN))

# %%
for i, im in enumerate(data_TN[:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')
    print(info_TN[i])

# %%
info_C11499 = pickle.load(open("../data/Corsika_11499/Corsika_11499_Qtot2000_Qst600_1_info.pkl", "rb"))
data_C11499 = np.load("../data/Corsika_11499/Corsika_11499_Qtot2000_Qst600_1_data.npy",allow_pickle=True,encoding='bytes')
print(len(info_C11499), len(data_C11499))
# Out:
# 224 224

# %%
for i, im in enumerate(data_C11499[:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im, interpolation='nearest', aspect='auto', cmap= 'gray')
    print(info_C11499[i])
# Out:
# {'index': 0, 'strings': {'charge': 1489.0999978873879, 'doms': array([{'dom_position': (124.97000122070312, -131.25, 493.6499938964844), 'key': (27, 1), 'qdom': 7.924999982118607},
#        {'dom_position': (124.97000122070312, -131.25, 476.6300048828125), 'key': (27, 2), 'qdom': 18.349999979138374},
#        {'dom_position': (124.97000122070312, -131.25, 459.6099853515625), 'key': (27, 3), 'qdom': 19.024999782443047},
#        {'dom_position': (124.97000122070312, -131.25, 442.5899963378906), 'key': (27, 4), 'qdom': 34.45000039041042},
#        {'dom_position': (124.97000122070312, -131.25, 425.57000732421875), 'key': (27, 5), 'qdom': 24.649999797344208},
#        {'dom_position': (124.97000122070312, -131.25, 408.54998779296875), 'key': (27, 6), 'qdom': 26.149999797344208},
#        {'dom_position': (124.97000122070312, -131.25, 357.489990234375), 'key': (27, 9), 'qdom': 41.80000056326389},
# ...
