# %%
from __future__ import division
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
def check(file_name):
    data = np.load(file_name, mmap_mode="r")['arr_0']
    fig = plt.figure(figsize=(15, 5))
    ax1 = fig.add_subplot(131)
    ax1.imshow(data[0]['image'][0,:,:,0], interpolation='nearest', aspect='auto', cmap= 'gray')
    ax2 = fig.add_subplot(132)
    ax2.imshow(data[0]['image'][0,:,:,1], interpolation='nearest', aspect='auto', cmap= 'gray')
    ax3 = fig.add_subplot(133)
    ax3.imshow(data[0]['image'][0,:,:,2], interpolation='nearest', aspect='auto', cmap= 'gray')
    print(data[0]['qtot'],data[0]['logan_veto'],data[0]['qst'])
    print(data[0]['primary'],data[0]['weight_val'],data['id'])

# %%
file_name = "/home/dup193/work/double_pulse/Images_de81_NuTau_1_1_00000001_data.npz"
check(file_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-4a6c587ba325> in <module>
#       1 file_name = "/home/dup193/work/double_pulse/Images_de81_NuTau_1_1_00000001_data.npz"
# ----> 2 check(file_name)
#
# <ipython-input-7-ef777a30afd9> in check(file_name)
#       1 def check(file_name):
# ----> 2     data = np.load(file_name, mmap_mode="r")['arr_0']
#       3     fig = plt.figure(figsize=(15, 5))
#       4     ax1 = fig.add_subplot(131)
#       5     ax1.imshow(data[0]['image'][0,:,:,0], interpolation='nearest', aspect='auto', cmap= 'gray')
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# ...

# %%
file_name = "/home/dup193/work/double_pulse/Images_de90_NuTau_1_1_00000001_data.npz"
check(file_name)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-daf58df89f59> in <module>
#       1 file_name = "/home/dup193/work/double_pulse/Images_de90_NuTau_1_1_00000001_data.npz"
# ----> 2 check(file_name)
#
# <ipython-input-7-ef777a30afd9> in check(file_name)
#       1 def check(file_name):
# ----> 2     data = np.load(file_name, mmap_mode="r")['arr_0']
#       3     fig = plt.figure(figsize=(15, 5))
#       4     ax1 = fig.add_subplot(131)
#       5     ax1.imshow(data[0]['image'][0,:,:,0], interpolation='nearest', aspect='auto', cmap= 'gray')
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# ...

# %%
file_name = "/home/dup193/work/double_pulse/Images_de108_NuTau_1_1_00000001_data.npz"
check(file_name)

# %%
file_name = "/home/dup193/work/double_pulse/Images_de117_NuTau_1_1_00000001_data.npz"
check(file_name)

# %%
file_name = "/home/dup193/work/double_pulse/Images_abs_NuTau_1_1_00000001_data.npz"
check(file_name)

# %%
file_name = "/home/dup193/work/double_pulse/Images_scat_NuTau_1_1_00000001_data.npz"
check(file_name)

# %%
file_name = "/home/dup193/work/double_pulse/Images_scatabs_NuTau_1_1_00000001_data.npz"
check(file_name)

# %%
file_name = "/home/dup193/work/double_pulse/Images_one_NuTau_1_1_00000001_data.npz"
check(file_name)

# %%
file_name = "/home/dup193/work/double_pulse/Images_minone_NuTau_1_1_00000001_data.npz"
check(file_name)

# %%
file_name = "/home/dup193/work/double_pulse/Images_minthree_NuTau_1_1_00000001_data.npz"
check(file_name)

# %%
#10670
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_10670_100x/Images_Corsika_10670_05000_05999_1_010670_005187_data.npz"
check(file_name)
print()
# Out:
# [1701.625] [(7.5289836, 7.234242, 7.5289836, 7.234242, -448.5, -451.90613, -1.)] [[(1516.225, 78,     0.   ) (  46.125, 72, 15582.768)
#   (  39.975, 77, 15542.566)]]

# %%
#11058
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11058_100x/Images_Corsika_11058_29000_29999_8_011058_029860_data.npz"
check(file_name)
print()
# Out:
# [1267.275] [(7.1055517, 6.9013042, 7.954202, 7.658052, 186.32, 186.32, 356.51886)] [[(918.075, 83,    0.    ) ( 93.9  , 80, 1703.8492)
#   ( 38.225, 27, 5148.5767)]]

# %%
#11362
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11362_100x/Images_Corsika_11362_49000_49999_6_011362_049610_data.npz"
check(file_name)
print()
# Out:
# [1201.95] [(7.764414, 7.769259, 7.764414, 7.769259, -254.87, -384.65723, -1.)] [[(987.375, 50,     0.   ) ( 59.95 , 49, 12733.384)
#   ( 53.025, 40, 14275.189)]]

# %%
#11499
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11499_100x/Images_Corsika_11499_97000_97999_5_011499_097563_data.npz"
check(file_name)
print()
# Out:
# [1018.525] [(7.527478, 7.386445, 7.530738, 7.3726196, -321.86, -348.93396, 0.30023813)] [[(411.125, 13,     0.   ) (242.8  , 20, 15707.073)
#   ( 88.3  , 12, 15664.13 )]]

# %%
#11637
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11637_100x/Images_Corsika_11637_99000_99999_6_011637_099611_data.npz"
check(file_name)
print()
# Out:
# [1610.925] [(7.622, 7.681828, 7.622, 7.681828, -305.93, -428.25092, 0.14126055)] [[(754.825, 59,     0.   ) (489.475, 50, 12617.254)
#   ( 92.95 , 58, 15469.563)]]
# [([4173824820,      86199], -13, 22121.926, [2900.0488 ,  164.50664, 1949.4182 ], [0.76715773, 6.2523136 ], -1344.289, 6330.027)] [0.00044365] [[(0, 4294967295, 152, 0)]]

# %%
#11808
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11808_100x/Images_Corsika_11808_98000_98999_0_011808_098020_data.npz"
check(file_name)
print()
# Out:
# [1663.425] [(14.66227, 14.73179, 11.410256, 13.184286, 171.74, 171.82913, -1.)] [[(1307.125, 13,     0.   ) (  73.625, 20, 15707.073)
#   (  35.4  , 21, 14021.747)]]

# %%
#11865
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11865_100x/Images_Corsika_11865_98000_98999_2_011865_098206_data.npz"
check(file_name)
print()
# Out:
# [1087.975] [(8.195085, 7.666451, 8.195085, 7.666451, 467.81, 467.85394, -1.)] [[(1007.625, 30,     0.   ) (  12.8  , 39, 12958.606)
#   (   7.575, 29, 17745.19 )]]

# %%
#11905
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11905_100x/Images_Corsika_11905_98000_98999_9_011905_098926_data.npz"
check(file_name)
print()
# Out:
# [1320.125] [(7.563725, 7.299394, 7.563725, 7.299394, -295.83, -312.69247, 105.96176)] [[(1049.675, 15,     0.   ) (  49.775, 16, 15824.318)
#   (  35.725,  8, 15718.487)]]

# %%
#11926
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11926_100x/Images_Corsika_11926_98000_98999_0_011926_098055_data.npz"
check(file_name)
print()
# Out:
# [1217.] [(8.383952, 8.222335, 8.383952, 8.222335, 335.52, 301.60953, -1.)] [[(1152.375, 74,     0.   ) (  22.375, 66, 17631.584)
#   (   6.9  , 73, 13948.177)]]

# %%
#11937
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11937_100x/Images_Corsika_11937_99000_99999_9_011937_099949_data.npz"
check(file_name)
print()
# Out:
# [1316.75] [(7.9590187, 8.05565, 7.9590187, 8.05565, 502.09, 490.65863, 1.1137445)] [[(1212.625, 76,     0.   ) (  24.   , 70, 15519.673)
#   (  16.2  , 75, 15698.002)]]

# %%
#11943
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_11943_100x/Images_Corsika_11943_83000_83999_0_011943_083079_data.npz"
check(file_name)
print()
# Out:
# [1501.075] [(7.2634835, 7.242979, 8.045361, 7.7805924, 160.56, 109.246574, 427.87323)] [[(579.375, 36,    0.    ) (320.15 , 79, 1674.004 )
#   (226.425, 80, 1686.3247)]]

# %%
#12040
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_12040_100x/Images_Corsika_12040_0099000_0099999_8_012040_099826_data.npz"
check(file_name)
print()
# Out:
# [2099.9] [(8.091142, 8.112016, 8.091142, 8.112016, 480.58, 465.408, -1.)] [[(2008.475, 22,     0.   ) (  25.525, 23, 15649.455)
#   (  23.625, 32, 15693.219)]]

# %%
#12161
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_12161_100x/Images_Corsika_12161_97000_97999_9_012161_097957_data.npz"
check(file_name)
print()
# Out:
# [1698.475] [(18.59745, 12.283858, 18.59745, 12.283858, 484.46, 387.89056, 0.05447993)] [[(1552.725, 76,     0.   ) (  47.5  , 75, 15698.002)
#   (  16.8  , 77, 15511.19 )]]

# %%
#12268
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_12268_100x/Images_Corsika_12268_98000_98999_8_012268_098882_data.npz"
check(file_name)
print()
# Out:
# [1142.675] [(7.5653844, 7.6303086, 7.5653844, 7.6303086, -331.23, -439.41943, -1.)] [[(973.575, 40,     0.   ) ( 32.025, 49, 10372.323)
#   ( 26.65 , 30, 14978.087)]]

# %%
#12332
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_12332_100x/Images_Corsika_12332_98000_98999_8_012332_098817_data.npz"
check(file_name)
print()
# Out:
# [1259.2] [(8.788258, 8.377157, 8.788258, 8.377157, 463.02, 463.02, 6.788867)] [[(1216.95, 73,     0.   ) (  10.6 , 74, 13948.177)
#   (   1.8 , 72, 15644.726)]]

# %%
#12379
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_12379_100x/Images_Corsika_12379_34000_34999_5_012379_034570_data.npz"
check(file_name)
print()
# Out:
# [1524.075] [(15.198466, 15.191187, 15.198466, 15.191187, 464.4, 266.63483, 213.527)] [[(1288.625, 18,     0.   ) (  12.725, 27, 15762.375)
#   (  10.4  , 26, 15565.003)]]

# %%
#9036
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_9036_100x/Images_Corsika_9036_95000_95999_4_009036_095434_data.npz"
check(file_name)
print()
# Out:
# [1012.015] [(8.683262, 8.032339, 8.683262, 8.032339, 297.76, 297.76, 0.)] [[(974.5458  , 75,     0.   ) (  5.284088, 69, 15701.24 )
#   (  5.023555, 68, 15734.848)]]

# %%
#9255
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_9255_100x/Images_Corsika_9255_99000_99999_9_009255_099971_data.npz"
check(file_name)
print()
# Out:
# [4267.225] [(7.8429604, 7.731122, 7.8429604, 7.731122, 505.72, 503.76453, -1.)] [[(4173.7524  , 74,     0.   ) (  46.963272, 73, 13948.177)
#   (  13.036941, 66, 17631.584)]]

# %%
#9622
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_9622_100x/Images_Corsika_9622_98000_98999_7_009622_098711_data.npz"
check(file_name)
print()
# Out:
# [1802.7532] [(16.343744, 14.805415, 15.981373, 15.23852, 500.84, 470.02847, 327.007)] [[(482.2296  , 28,     0.   ) ( 80.05173 , 83, 20856.16 )
#   ( 63.610207, 20, 15641.533)]]

# %%
#10281
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_10281_100x/Images_Corsika_10281_09000_09999_5_009549_05_data.npz"
check(file_name)
print()
# Out:
# [1709.3942] [(999., -999., 999., -999., -999., -999., -999.)] [[(1661.2522   , 20,     0.   ) (   3.9323733, 21, 13870.477)
#   (   2.5026045, 12, 15607.295)]]
# [([2902562157,    1987356], 2212, 60565.5, [-3880.311 , -1619.0771,  1948.62  ], [1.2471513, 3.466695 ], -5690.8716, -1.)] [0.02395013]

# %%
#10282
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_10282_100x/Images_Corsika_10282_11000_11999_4_011415_00_data.npz"
check(file_name)
print()
# Out:
# [1006.9467] [(8.665708, 8.3790655, 8.665708, 8.3790655, -8.62, -8.3287, 0.)] [[(951.69135  , 75,     0.   ) (  7.546465 , 69, 15701.24 )
#   (  6.0516796, 76, 15698.002)]]
# [([3580819834,     432314], 1000020040, 138810., [-1898.9811,  -545.5591,  1949.69  ], [0.7526121, 3.7190523], 903.81055, -1.)] [0.01220344]

# %%
#10309
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_10309_100x/Images_Corsika_10309_15000_15999_1_010309_015113_data.npz"
check(file_name)
print()
# Out:
# [2578.6743] [(7.576476, 7.5550265, 7.576476, 7.5550265, -463.95, -461.54416, 0.3384415)] [[(1938.0294 , 59,     0.   ) ( 222.37582, 58, 15469.563)
#   ( 197.39163, 67, 14376.813)]]

# %%
#10475
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_10475_100x/Images_Corsika_10475_19000_19999_8_019806_00_data.npz"
check(file_name)
print()
# Out:
# [1004.7649] [(7.7329535, 7.438891, 7.7329535, 7.438891, 504.02, 489.90845, 105.96176)] [[(860.7992  , 15,     0.   ) ( 50.182564, 14, 15475.448)
#   ( 35.004704,  7, 15665.432)]]

# %%
#10651
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_10651_100x/Images_Corsika_10651_19000_19999_9_019965_00_data.npz"
check(file_name)
print()
# Out:
# [1759.3782] [(8.845269, 8.093432, 8.845269, 8.093432, 464.62, 464.62, 0.0995898)] [[(1708.3143   , 4,     0.   ) (  11.129561 , 3, 15647.253)
#   (   3.5019217, 5, 15608.076)]]

# %%
#10668
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_10668_100x/Images_Corsika_10668_09000_09999_7_010668_009771_data.npz"
check(file_name)
print()
# Out:
# [1429.9784] [(19.323057, 14.074664, 19.323057, 14.074664, 497.06, 421.64264, 0.08702359)] [[(1319.8552   , 74,     0.   ) (   7.8395424, 73, 13948.177)
#   (   2.276327 , 67, 21040.637)]]

# %%
#10784
file_name = "/home/dup193/work/double_pulse/data/images_3str/Corsika_10784_100x/Images_Corsika_10784_19000_19999_9_019964_00_data.npz"
check(file_name)
print()
# Out:
# [1160.1783] [(15.849998, 14.691147, 7.727911, 12.604769, 399.41, 309.1986, 149.67096)] [[(491.28568, 69,     0.   ) (212.7955 , 62, 15602.474)
#   ( 87.73536, 61, 15640.328)]]
