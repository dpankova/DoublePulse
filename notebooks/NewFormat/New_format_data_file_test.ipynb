# %%
from __future__ import division
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
mm_array = np.load("../../data/new_data/NewFormat_NuTau_Weights_1_data.npy", mmap_mode="r+")

# %%
print(mm_array[0])
# Out:
# [((1, 4294967295, 0, 0), 32941.242, -15., (3.9867737, 339579.3, 6.2831855, 1., 32941.242, 1.5, 1., 0.6061273, 2.2241476e-05, 1., 1., 2677.034, 0.5, -16., 1665.5576, 0.382891, 0., -16., -1., 0.119364, 0.9999938, 17658.566, 264143.78, -1., 0., 1.0955385e-34, 4.0539996e+12, 463.13895, 1., 848.7699, 3.1415927, 8.072709e-35, 32941.242, 1., 4.3867873e+10, 3.69897, 12.566371, 2908.0742, 10000, 2.0269998e+12, 7., 2.2241615e-05, 0.), ( True,  True,  True,  True,  True,  True,  True))]

# %%
mm_array = np.load("../../data/new_data/NewFormat_NuTauCC_Qtot1000_Qst400_10_data.npy", mmap_mode ="r+")

# %%
for i, im in enumerate(mm_array['image'][:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im.reshape(300,60), interpolation='nearest', aspect='auto', cmap= 'gray')
    print(mm_array['neutrino'][i])
# Out:
# [(16, 72539.74, [-497.52084,  524.5688 , 1947.959  ], [0.63716716, 2.2840686 ], 3164.82, 1958.3597)]
# [(4294967280, 10552.142, [ 6338623.  ,  -217082.75, -7008046.5 ], [2.405968 , 6.2489305], -31518262., 9451826.)]
# [(4294967280, 125751.18, [-695.9542, 1453.5651, 1947.7963], [0.7362494, 1.9228748], -373.93246, 3041.0022)]

# %%
mm_array = np.load('/fastio2/dasha/double_pulse/weights.npy', mmap_mode='r')

# %%
print(mm_array[0])
# Out:
# [((1, 4294967295, 0, 0), 32941.242, -15., (3.9867737, 339579.3, 6.2831855, 1., 32941.242, 1.5, 1., 0.6061273, 2.2241476e-05, 1., 1., 2677.034, 0.5, -16., 1665.5576, 0.382891, 0., -16., -1., 0.119364, 0.9999938, 17658.566, 264143.78, -1., 0., 1.0955385e-34, 4.0539996e+12, 463.13895, 1., 848.7699, 3.1415927, 8.072709e-35, 32941.242, 1., 4.3867873e+10, 3.69897, 12.566371, 2908.0742, 10000, 2.0269998e+12, 7., 2.2241615e-05, 0.), ( True,  True,  True,  True,  True,  True,  True))]

# %%
mm_array = np.load('/fastio2/dasha/double_pulse/data.npy', mmap_mode='r')

# %%
for i, im in enumerate(mm_array['image'][:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im.reshape(300,60), interpolation='nearest', aspect='auto', cmap= 'gray')
    print(mm_array['neutrino'][i])
# Out:
# [(16, 363207.84, [-3248.6345, -1690.0543,  1946.9481], [1.1377063, 3.4470775], -4675.9746, 4154.806)]
# [(16, 2880998.8, [ 573.0816, 1551.6466, 1947.7854], [0.63338596, 1.5602827 ], 2017.3586, 2329.5605)]
# [(16, 640914.56, [-1516.0851 ,   379.57547,  1947.8083 ], [0.7196309, 3.221025 ], 2772.5703, 2043.8286)]

# %%
mm_array = np.load("../../data/new_data/NewFormat_NuE_Weights_1_data.npy", mmap_mode="r+")

# %%
print(mm_array[0])
# Out:
# [((167, 4294967295, 1, 0), 10254.318, 11., (0.5230934, 204444.34, 6.2831855, 1., 10254.318, 1.5, 1., 1.0461615, 7.675599e-06, 1., 1., 744.678, 0.5, 12., -1., 0.0195732, 0., 12., -1., 0.125333, 0.9999968, -1., 85861.58, -1., 0., 6.279662e-35, 2.5173177e+11, 590.9554, 1., 1195.7852, 3.1415927, 4.7081034e-35, 10254.318, 1., 4.544667e+10, 3.69897, 12.566371, 931.67285, 10000, 1.25865886e+11, 7., 7.675623e-06, 0.), ( True,  True,  True,  True,  True,  True,  True))]

# %%
mm_array = np.load("../../data/new_data/NewFormat_NuECC_Qtot1000_Qst400_10_0_data.npy", mmap_mode ="r+")

# %%
for i, im in enumerate(mm_array['image'][:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im.reshape(300,60), interpolation='nearest', aspect='auto', cmap= 'gray')
    print(mm_array['neutrino'][i])
# Out:
# [(12, 35197.49, [2083.3767, 3880.8098, 1946.4781], [1.154391 , 1.1157396], -8353.768, 5368.265)]
# [(12, 152502.67, [ -562.5993, -2084.3164,  1947.6344], [0.573412 , 4.4886947], -421.6324, 2980.4434)]
# [(4294967284, 22285.312, [ 504.21765, 1289.9928 , 1947.8495 ], [0.54158074, 0.92953223], 2703.079, 2066.6226)]
