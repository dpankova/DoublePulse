# %%
from __future__ import division
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
mm_array = np.load("../../data/new_data/NewFormat_NuMu_Weights_1_data.npy", mmap_mode="r+")

# %%
print(mm_array[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-2a787e307337> in <module>
# ----> 1 print(mm_array['image'][0])
#
# ~/anaconda3/envs/tf-gpu/lib/python3.7/site-packages/numpy/core/memmap.py in __getitem__(self, index)
#     329
#     330     def __getitem__(self, index):
# --> 331         res = super(memmap, self).__getitem__(index)
#     332         if type(res) is memmap and res._mmap is None:
#     333             return res.view(type=ndarray)
#
# ValueError: no field of name image

# %%
mm_array = np.load("../../data/new_data/NewFormat_NuECC_Qtot1000_Qst400_10_0_data.npy", mmap_mode ="r+")

# %%
for i, im in enumerate(mm_array['image'][:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im.reshape(300,60), interpolation='nearest', aspect='auto', cmap= 'gray')
    print(mm_array['neutrino'][i])
# Out:
# [(12, 35197.49, [2083.3767, 3880.8098, 1946.4781], [1.154391 , 1.1157396], -8353.768, 5368.265)]
# [(12, 152502.67, [ -562.5993, -2084.3164,  1947.6344], [0.573412 , 4.4886947], -421.6324, 2980.4434)]
# [(4294967284, 22285.312, [ 504.21765, 1289.9928 , 1947.8495 ], [0.54158074, 0.92953223], 2703.079, 2066.6226)]

# %%
mm_array = np.load('/fastio2/dasha/double_pulse/weights.npy', mmap_mode='r')

# %%
print(mm_array[0], mm_array.shape)
# Out:
# [((9000, 4294967295, 1, 0), 72539.74, 15., (2.2840686, 255006.62, 6.2831855, 1., 72539.74, 1.5, 1., 0.63716716, 3.6081936e-05, 1., 1., 1995.406, 0.5, 16., 1241.5757, 0.352358, 0., 16., -1., 0.389041, 0.9999931, 21393.785, 176532.4, -1., 0., 2.3667204e-34, 2.1686523e+13, 579.3087, 1., 814.46735, 3.1415927, 1.7467695e-34, 72539.74, 1., 4.4266238e+10, 3.69897, 12.566371, 1958.3597, 10000, 1.0843262e+13, 7., 3.6082187e-05, 0.), ( True,  True,  True,  True,  True,  True,  True))] (6374299, 1)

# %%
mm_array = np.load('/fastio2/dasha/double_pulse/weights_NuTau.npy', mmap_mode='r')

# %%
print(mm_array[0], mm_array.shape)
# Out:
# [((9218, 4294967295, 0, 0), (4294967280, 10549.68, [1824491.1 , -846848.4 , -323742.88], [1.7301265, 5.848404 ], -6784571., 2036735.8), [8796.206 , 1753.4728,    0.    ,    0.    ,    0.    ,    0.    ,    0.    ,    0.    ,    0.    ,    0.    ], [-1.500000e+01, -2.000001e+09,  0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00,  0.000000e+00], (5.848404, 1401995.6, 6.2831855, 1., 10549.68, 1.5, 1., 1.7301265, 3.6503472e-05, 1., 1., 6487.9233, 0.5, -16., 5552.149, 0.166211, 0., -16., -1., 0.00499058, 0.99998504, 12446.903, 1275819.8, -1., 0., 4.3551153e-35, 1.1034334e+12, 674.5321, 1., 771.10736, 3.1415927, 3.2219735e-35, 10549.68, 1., 4.0141128e+10, 3.69897, 12.566371, 5889.9116, 10000, 5.517167e+11, 7., 3.6504018e-05, 0.), (False,  True,  True, False,  True,  True,  True))] (6374299, 1)

# %%
mm_array = np.load('/fastio2/dasha/double_pulse/data_NuMuCC.npy', mmap_mode='r')

# %%
for i, im in enumerate(mm_array['image'][:1]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im.reshape(300,60), interpolation='nearest', aspect='auto', cmap= 'gray')
    print(np.max(im))
# Out:
# 0.050828066

# %%
mm_array = np.load("../../data/new_data/NewFormat_NuE_Weights_1_data.npy", mmap_mode="r+")

# %%
print(mm_array[0])
# Out:
# [((167, 4294967295, 1, 0), 10254.318, 11., (0.5230934, 204444.34, 6.2831855, 1., 10254.318, 1.5, 1., 1.0461615, 7.675599e-06, 1., 1., 744.678, 0.5, 12., -1., 0.0195732, 0., 12., -1., 0.125333, 0.9999968, -1., 85861.58, -1., 0., 6.279662e-35, 2.5173177e+11, 590.9554, 1., 1195.7852, 3.1415927, 4.7081034e-35, 10254.318, 1., 4.544667e+10, 3.69897, 12.566371, 931.67285, 10000, 1.25865886e+11, 7., 7.675623e-06, 0.), ( True,  True,  True,  True,  True,  True,  True))]

# %%
mm_array = np.load("../../data/new_data/NewFormat_NuECC_Qtot1000_Qst400_10_0_data.npy", mmap_mode ="r+")

# %%
for i, im in enumerate(mm_array['image'][:3]):
    fig = plt.figure(figsize=(5, 5))
    ax = fig.add_subplot(111)
    ax.imshow(im.reshape(300,60), interpolation='nearest', aspect='auto', cmap= 'gray')
    print(mm_array['neutrino'][i])
# Out:
# [(12, 35197.49, [2083.3767, 3880.8098, 1946.4781], [1.154391 , 1.1157396], -8353.768, 5368.265)]
# [(12, 152502.67, [ -562.5993, -2084.3164,  1947.6344], [0.573412 , 4.4886947], -421.6324, 2980.4434)]
# [(4294967284, 22285.312, [ 504.21765, 1289.9928 , 1947.8495 ], [0.54158074, 0.92953223], 2703.079, 2066.6226)]

# %%
d =np.load('/fastio2/dasha/double_pulse/data_NuENC.npy', mmap_mode='r')
e = np.load('/fastio2/dasha/double_pulse/data_NuECC.npy', mmap_mode='r')

# %%
values, counts = np.unique(d['meson']['pdg'], return_counts=True)
print(values, counts, counts*100/sum(counts))
values, counts = np.unique(e['meson']['pdg'], return_counts=True)
print(values, counts, counts*100/sum(counts))

#for i in d['meson']['pdg']:
#    if i != 12:
#        print(i)
    #print(d['meson']['pdg'])
# Out:
# [        12 4294967284] [1275758  178407] [87.73130972 12.26869028]
# [        11 4294967285] [1146093  284984] [80.08604708 19.91395292]

# %%
-11+2**32
# Out:
# 4294967285

# %%
ids = d['id']
print(ids[:1])
# Out:
# [[(3868, 4294967295, 8, 0)]]

# %%
w = np.load('/fastio2/dasha/double_pulse/weights_NuE.npy', mmap_mode='r')

# %%
print(w['pdg'][:10])
# Out:
# [[[-2.000001e+09  1.100000e+01  0.000000e+00  0.000000e+00  0.000000e+00
#     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
#
#  [[ 1.200000e+01 -2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00
#     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
#
#  [[ 1.100000e+01 -2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00
#     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
#
#  [[-2.000001e+09  1.200000e+01  0.000000e+00  0.000000e+00  0.000000e+00
#     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
#
#  [[-1.200000e+01 -2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00
#     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
#
#  [[-2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
#
#  [[ 1.100000e+01 -2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
print(w[:1]['energy'],w[:1]['pdg'])
# Out:
# [[[367631.72  74135.63      0.        0.        0.        0.        0.
#         0.        0.        0.  ]]] [[[-2.000001e+09  1.100000e+01  0.000000e+00  0.000000e+00  0.000000e+00
#     0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]]

# %%
count = 0 
for i in w['pdg']:
    s = set(i[0])
    if ((12 in s) or (-12 in s)) and ((11 in s) or (-11 in s)): 
        count  = count+1
print(count, count/len(w['pdg'])*100)
# Out:
# 8929 0.05261126953544703

# %%
for i in w['pdg'][:10]:
    if len(i[0])>1: 
        print(i)
# Out:
# [[-2.000001e+09  1.100000e+01  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
# [[ 1.200000e+01 -2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
# [[ 1.100000e+01 -2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
# [[-2.000001e+09  1.200000e+01  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
# [[-1.200000e+01 -2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
# [[-2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]]
# [[ 1.100000e+01 -2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00
# ...

# %%
values, counts = np.unique(w['pdg'], return_counts=True, axis =0)
z = zip(values, counts)
for i in z:
    print(i[0],i[1])
# Out:
# [[-2.000001e+09 -1.200000e+01  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]] 235882
# [[-2.000001e+09 -1.100000e+01  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]] 603479
# [[-2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]] 54132
# [[-2.000001e+09  1.100000e+01  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]] 3150942
# [[-2.000001e+09  1.200000e+01  0.000000e+00  0.000000e+00  0.000000e+00
#    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00]] 1408676
# [[-16.  15.   0.   0.   0.   0.   0.   0.   0.   0.]] 8316
# [[-14.  13.   0.   0.   0.   0.   0.   0.   0.   0.]] 26159
# [[-1.200000e+01 -2.000001e+09  0.000000e+00  0.000000e+00  0.000000e+00
# ...
